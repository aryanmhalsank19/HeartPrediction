# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\SEJAL WAGH\Downloads\Cleveland Dataset\dataset.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   0       145   233    1        2      150      0      2.3      2
# 1   67    1   3       160   286    0        2      108      1      1.5      1
# 2   67    1   3       120   229    0        2      129      1      2.6      1
# 3   37    1   2       130   250    0        0      187      0      3.5      2
# 4   41    0   1       130   204    0        2      172      0      1.4      0
#
#    ca  thal  target
# 0   0     2       0
# 1   3     1       1
# 2   2     3       1
# 3   0     1       0
# 4   0     1       0

# %%
df.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   45    1   0       110   264    0        0      132      0      1.2
# 299   68    1   3       144   193    1        0      141      0      3.4
# 300   57    1   3       130   131    0        0      115      1      1.2
# 301   57    0   1       130   236    0        2      174      0      0.0
# 302   38    1   2       138   175    0        0      173      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       1
# 299      1   2     3       1
# 300      1   1     3       1
# 301      1   1     1       1
# 302      0   0     1       0

# %%
df.shape
# Out:
# (303, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# Load Cleveland Heart Disease dataset from UCI Repository manually
# Download the dataset from: https://archive.ics.uci.edu/ml/datasets/Heart+Disease
# and save it as 'heart.csv' in the working directory
# column_names = [
#     "age", "sex", "cp", "trestbps", "chol", "fbs", "restecg",
#     "thalach", "exang", "oldpeak", "slope", "ca", "thal", "target"
# ]

# %%
df['target'].value_counts()
# Out:
# target
# 0    164
# 1    139
# Name: count, dtype: int64

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import mutual_info_classif
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv(r"C:\Users\SEJAL WAGH\Downloads\Cleveland Dataset\Heart_disease_cleveland_new.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   0       145   233    1        2      150      0      2.3      2
# 1   67    1   3       160   286    0        2      108      1      1.5      1
# 2   67    1   3       120   229    0        2      129      1      2.6      1
# 3   37    1   2       130   250    0        0      187      0      3.5      2
# 4   41    0   1       130   204    0        2      172      0      1.4      0
#
#    ca  thal  target
# 0   0     2       0
# 1   3     1       1
# 2   2     3       1
# 3   0     1       0
# 4   0     1       0

# %%
# Extract features (X) and target variable (y)
X = df.drop(columns=['target'])
y = df['target']  # Convert target to binary (0 or 1)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=23)

# %%
# Calculate mutual information scores for each feature
mi_scores = mutual_info_classif(X_train, y_train, discrete_features='auto', random_state=23)

# %%
# Create a DataFrame to display the mutual information scores for each feature
feature_mi_df = pd.DataFrame({'Feature': X.columns, 'Mutual_Information': mi_scores})
feature_mi_df = feature_mi_df.sort_values(by='Mutual_Information', ascending=False)

# %%
# Display the features with their corresponding mutual information scores
print("Mutual Information Scores:")
print(feature_mi_df)
# Out:
# Mutual Information Scores:
#      Feature  Mutual_Information
# 2         cp            0.175804
# 12      thal            0.144046
# 8      exang            0.108096
# 11        ca            0.101152
# 9    oldpeak            0.097061
# 7    thalach            0.093386
# 10     slope            0.091196
# 4       chol            0.060754
# 6    restecg            0.047544
# 3   trestbps            0.032778
# 5        fbs            0.022352
# 0        age            0.000000
# 1        sex            0.000000

# %%
# Select the top k features based on mutual information scores
k = 10
selected_features = feature_mi_df.head(k)['Feature'].tolist()

# %%
# Train a Random Forest Classifier using the selected features
clf = RandomForestClassifier(random_state=23)
clf.fit(X_train[selected_features], y_train)
# Out:
# RandomForestClassifier(random_state=23)

# %%
# Make predictions on the test set
y_pred = clf.predict(X_test[selected_features])

# %%
# Calculate accuracy on the test set
accuracy = accuracy_score(y_test, y_pred)
print(f"\nAccuracy with {k} selected features: {accuracy:.2f}")
# Out:
# Accuracy with 10 selected features: 0.82
