# %%
#KNN with 7 Selected Features

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Load the heart dataset
heart_data = pd.read_csv('clevland_dataset.csv')

# Separate features (X) and target variable (Y)
selected_features = ['cp','thalach','exang','oldpeak','chol','ca','thal']
X = heart_data[selected_features]
Y = heart_data['target']

# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, stratify=Y, random_state=42)

# Standardize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Create a KNN classifier
model = KNeighborsClassifier(n_neighbors=10)

# Train the KNN model
model.fit(X_train, Y_train)

# Accuracy on training data
train_pred = model.predict(X_train)
train_accuracy = accuracy_score(train_pred, Y_train)
print('Accuracy on Training data : ', train_accuracy)

# Accuracy on test data
test_pred = model.predict(X_test)
test_accuracy = accuracy_score(test_pred, Y_test)
print('Accuracy on Test data : ', test_accuracy)


# numpy array static data
#['cp','thalach','exang','oldpeak','chol','ca','thal'] Selected Features 7
user_data = np.array([3,150,0,2.6,229,2,1]).reshape(1, -1)

#scalar for standardize
user_data_scaled = scaler.transform(user_data)

# Prediction
prediction = model.predict(user_data_scaled)
if prediction[0] == 0:
    result = "The Person does not have a Heart Disease"
else:
    result = "The Person has Heart Disease"

print(result)
# Out:
# Accuracy on Training data :  0.8679245283018868
# Accuracy on Test data :  0.8351648351648352
# The Person has Heart Disease
# /home/aryanmhalsank/.local/lib/python3.8/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
#KNN with 9 Selected Features

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score


# Load the heart dataset
heart_data = pd.read_csv('clevland_dataset.csv')

# Separate features (X) and target variable (Y)
selected_features = ['cp','thalach','exang','oldpeak','chol','ca','thal','restecg','slope']
X = heart_data[selected_features]
Y = heart_data['target']

# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, stratify=Y, random_state=42)

# Standardize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Create a KNN classifier
model = KNeighborsClassifier(n_neighbors=10)

# Train the KNN model
model.fit(X_train, Y_train)

# Accuracy on training data
train_pred = model.predict(X_train)
train_accuracy = accuracy_score(train_pred, Y_train)
print('Accuracy on Training data : ', train_accuracy)

# Accuracy on test data
test_pred = model.predict(X_test)
test_accuracy = accuracy_score(test_pred, Y_test)
print('Accuracy on Test data : ', test_accuracy)


# numpy array static data
#['cp','thalach','exang','oldpeak','chol','ca','thal'] Selected Features 7
user_data = np.array([3,150,0,2.6,229,2,1,2,2]).reshape(1, -1)

#scalar for standardize
user_data_scaled = scaler.transform(user_data)

# Prediction
prediction = model.predict(user_data_scaled)
if prediction[0] == 0:
    result = "The Person does not have a Heart Disease"
else:
    result = "The Person has Heart Disease"

print(result)
# Out:
# Accuracy on Training data :  0.8584905660377359
# Accuracy on Test data :  0.8461538461538461
# The Person has Heart Disease
# /home/aryanmhalsank/.local/lib/python3.8/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
#KNN with 14 Selected Features

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, roc_auc_score, log_loss, recall_score

# Load the heart dataset
heart_data = pd.read_csv('clevland_dataset.csv')

# Separate features (X) and target variable (Y)
selected_features = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal']
X = heart_data[selected_features]
Y = heart_data['target']

# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, stratify=Y, random_state=42)

# Standardize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Create a KNN classifier
model = KNeighborsClassifier(n_neighbors=5)

# Train the KNN model
model.fit(X_train, Y_train)

# Accuracy on training data
train_pred = model.predict(X_train)
train_accuracy = accuracy_score(train_pred, Y_train)
print('Accuracy on Training data : ', train_accuracy)

# Accuracy on test data
test_pred = model.predict(X_test)
test_accuracy = accuracy_score(test_pred, Y_test)
print('Accuracy on Test data : ', test_accuracy)


# numpy array static data
#['cp','thalach','exang','oldpeak','chol','ca','thal'cp,chol,thalach,exang,oldpeak,ca,thal​] Selected Features 7
user_data = np.array([64,1,3,128,263,0,0,105,1,0.2,1,1,3]).reshape(1, -1)

#scalar for standardize
user_data_scaled = scaler.transform(user_data)

# Prediction
prediction = model.predict(user_data_scaled)
if prediction[0] == 0:
    result = "The Person does not have a Heart Disease"
else:
    result = "The Person has Heart Disease"

print(result)

# Confusion matrix
CM = confusion_matrix(Y_test, test_pred)

# Plotting the confusion matrix
plt.figure(figsize=(6, 4))
sns.heatmap(CM, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# Sensitivity and Specificity
TN = CM[0][0]
FN = CM[1][0]
TP = CM[1][1]
FP = CM[0][1]
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)

# Log Loss
test_pred_proba = model.predict_proba(X_test)
logloss = log_loss(Y_test, test_pred_proba)

# AUROC
auroc = roc_auc_score(Y_test, test_pred_proba[:,1])

print('Sensitivity:', sensitivity)
print('Specificity:', specificity)
print('Log Loss:', logloss)
print('AUROC:', auroc)
# Out:
# Accuracy on Training data :  0.8962264150943396
# Accuracy on Test data :  0.8131868131868132
# The Person has Heart Disease
# /home/aryanmhalsank/.local/lib/python3.8/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 86
#      83 logloss = log_loss(Y_test, test_pred_proba)
#      85 # AUROC
# ---> 86 auroc = roc_auc_score(Y_test, test_pred_proba)
#      88 print('Sensitivity:', sensitivity)
#      89 print('Specificity:', specificity)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
# ...
